# %% [markdown]
# <a href="https://colab.research.google.com/github/taticorrea/dataengineering/blob/main/RestAPI/youtube_API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from googleapiclient.discovery import build
import pandas as pd

import json

# %%
api_key='AIzaSyC24ThsL_nYMSmJi_4-d90esNWMKwoLcJo'
video_id = "lF9QRXkIgIM" #BDBE lF9QRXkIgIM  #canal-pessoal IxZcdFA8G-w

def video_comments(video_id):
	
  comments = []
  authors = []
  dates = []

  youtube = build('youtube', 'v3', developerKey=api_key)
  
  request=youtube.commentThreads().list(
        part='snippet',
        videoId=video_id
        )
 
  while request:
    response = request.execute()
		
    for item in response['items']:
        
      comment=item['snippet']['topLevelComment']['snippet']['textDisplay']
      comments.append(comment)
      
      author=item['snippet']['topLevelComment']['snippet']['authorDisplayName']
      authors.append(author)
      
      date=item['snippet']['topLevelComment']['snippet']['updatedAt']
      dates.append(date)
      
      request = youtube.commentThreads().list_next(request, response)

  df = pd.DataFrame({'comentarios':comments,'autores':authors,'data':dates})
  
  return df

df = video_comments(video_id)  
df
# Out:
#                                             comentarios  \
# 0                                       Raianny Proença
# 1                                         VITOR MARCELO
# 2                                      wled Lucas Cunha
# 3     Parabéns Elisangela Bernado Alves pela partici...
# 4                                       Camila da Unico
# ...                                                 ...
# 2162                                           Topo dms
# 2163                                Top demais o evento
# 2164  <a href="http://www.youtube.com/results?search...
# 2165                                      Sucesso total
# 2166                                   Me dê o brindeee
#
#                                 autores                  data
# 0                         Loiva Casaril  2022-10-28T02:41:58Z
# 1       Anna Carolina Gomes De Oliveira  2022-10-27T14:36:31Z
# 2     Guilherme Pereira Albino da Silva  2022-10-24T20:01:15Z
# 3                        Goku Bomberman  2022-10-24T18:14:46Z
# 4          Marilyn de Medeiros Carvalho  2022-10-24T16:24:44Z
# ...                                 ...                   ...
# 2162                           MAGAIVER  2022-10-22T13:25:47Z
# 2163        vitor cezar ventura marcelo  2022-10-22T13:25:36Z
# 2164                      Augusto Cezar  2022-10-22T13:25:20Z
# 2165                   Glauber Oliveira  2022-10-22T13:24:41Z
# 2166                       Gabriel_lima  2022-10-22T13:23:52Z
#
# [2167 rows x 3 columns]

# %%
df_tatiane = df[(df.comentarios.str.contains('Corrêa') | \
    df.comentarios.str.contains('Correa') | \
    df.comentarios.str.contains('correa') | \
    df.comentarios.str.contains('corrêa') | \
    df.comentarios.str.contains('tatiane') | \
    df.comentarios.str.contains('Tatiane') | \
    df.comentarios.str.contains('Tatiana') | \
    df.comentarios.str.contains('tatiana')
    )
]

# %%
df_tatiane
# Out:
#                                             comentarios             autores  \
# 39                                      Tatiane Correia           Kim Ramos
# 63                    Parabéns a Tatiane Corrêa!!!! 🎉🎉🎉        Raissa Couto
# 132   Parabéns Tatiane corrêa. Pela participação no ...  Luciano Figueiredo
# 133                                      Tatiane corrêa  Luciano Figueiredo
# 172                        Vai tatiane correa boa sorte        Lucas Gondim
# ...                                                 ...                 ...
# 1840                                    Tatiane correia     Cristiano Alves
# 1871                                    Tatiane Correia     Filipe Oliveira
# 1879                    Tatiane Correa da Costa e Silva        Victor Silva
# 1940                                    Tatiane Corrêa✋          Ruan Pablo
# 2035                                    Tatiana Correa.        daniel Prata
#
#                       data
# 39    2022-10-23T00:29:24Z
# 63    2022-10-22T21:59:43Z
# 132   2022-10-22T20:34:34Z
# 133   2022-10-22T20:32:59Z
# 172   2022-10-22T20:01:49Z
# ...                    ...
# 1840  2022-10-22T13:36:02Z
# 1871  2022-10-22T13:35:24Z
# 1879  2022-10-22T13:35:07Z
# 1940  2022-10-22T13:33:25Z
# 2035  2022-10-22T13:31:18Z
#
# [69 rows x 3 columns]

# %%
list(df_tatiane.autores.drop_duplicates())
# Out:
# ['Kim Ramos',
#  'Raissa Couto',
#  'Luciano Figueiredo',
#  'Lucas Gondim',
#  'Vitor',
#  'Gabriel Soares',
#  'Caroline Cruz',
#  'Leonardo Lemos',
#  'Luiza Helena Rizzo',
#  'Anna Coelho - SAP BW Consultant',
#  'José Weslley Pereira da Silva',
#  'Elias da Costa e Silva',
#  'Lê CCS',
#  'Vinícius Diniz',
#  'Andreza Paiva',
#  'Pedro Sobrinho',
#  'Malu Ramos',
#  'Rebeca Batalha',
#  'Carol Souza',
#  'Bernardo Almeida',
#  'Leonardo Castro',
#  'Thais Guerini',
#  'Rodrigo Carvalho',
#  'Juan Leite',
#  'Pedro Maia',
#  'Priscyla B Peres',
#  'Raphael Balmant',
#  'Karyna Gimenez',
#  'Victor Hugo Cosmos',
#  'Caroline Otavio',
#  'Bruno R. Adami',
#  'Fernanda Severo',
#  'Ricardo Ogando',
#  'Thiago Nogueira',
#  'Otavio Roriz',
#  'Pablo Meireles',
#  'J. Victor Farias',
#  'Juruna Prata',
#  'Paloma Makly',
#  'Thales Yuri',
#  'Luiz Vicente',
#  'Vinicius Oliveira',
#  'Leandro Soares',
#  'Tiago dos Santos Mendonça',
#  'Julio Moreira',
#  'Felipe Zanette',
#  'Victor Oliveira',
#  'Rodolfo Rocha',
#  'Ayslana Sonally da Silva Souza',
#  'Gabriel Ramos',
#  'Saulo Ramalho',
#  'Rodolpho Degen',
#  'barebruno',
#  'Jônatas',
#  'wallace alves fonseca',
#  'Mariana Pimenta',
#  'Je Olii',
#  'Lucas Do Livramento',
#  'Leandro Soares Faria',
#  'Cristiano Alves',
#  'Filipe Oliveira',
#  'Victor Silva',
#  'Ruan Pablo',
#  'daniel Prata']

# %%
len(list(df_tatiane.autores.drop_duplicates()))
# Out:
# 64

# %%
df_tatiane[df_tatiane.autores== 'Je Olii']
# Out:
#                                   comentarios  autores                  data
# 1574  Que maravilha, vim pela Tatiane Corrêa!  Je Olii  2022-10-22T13:43:43Z

# %%
df[df.comentarios.str.contains('Victor O’Briam*')]
# Out:
#                                             comentarios           autores  \
# 157     Parabéns, Victor O’Briam Quevedo!!!! Arrebenta!      Gustavo Maia
# 251   Parabéns, Victor O’Briam Quevedo pela particip...     Leandro Lessa
# 314   Parabéns, Victor O’Briam Quevedo pela particip...     Gustavo Neves
# 315   Parabéns, Victor O’Briam Quevedo pela particip...     Gustavo Neves
# 316   Parabéns, Victor O’Briam Quevedo pela particip...     Gustavo Neves
# 326   Parabéns, Victor O’Briam Quevedo pela particip...       Pedro Haick
# 327                              Victor O’Brian Quevedo   Henrique Galvan
# 328                              Victor O’Brian Quevedo   Henrique Galvan
# 329                              Victor O’Brian Quevedo   Henrique Galvan
# 330                              Victor O’Brian Quevedo   Henrique Galvan
# 497                              Victor O’Brian Quevedo  Leon Giangarelli
# 850                              Victor O’Briam Quevedo       ANA SCHMIDT
# 898                          Victor O’Briam o melhor!!!      Raquel Gomes
# 1474     Victor O’Briam Quevedo entende do assunto hein    Shigue Fishing
# 1481                    Victor O’Briam Quevedo é o cara    Shigue Fishing
# 1489           Victor O’Briam Quevedo um Deus dos dados    Shigue Fishing
# 1823               Victor O’Briam Quevedo é um monstro!    Shigue Fishing
# 1847                             Victor O’Briam Quevedo    Shigue Fishing
# 2091                       Victor O’Brian é fera demais  Marcello Tonello
#
#                       data
# 157   2022-10-22T20:19:13Z
# 251   2022-10-22T18:57:19Z
# 314   2022-10-22T17:48:18Z
# 315   2022-10-22T17:48:04Z
# 316   2022-10-22T17:47:43Z
# 326   2022-10-22T17:40:24Z
# 327   2022-10-22T17:40:02Z
# 328   2022-10-22T17:39:53Z
# 329   2022-10-22T17:39:45Z
# 330   2022-10-22T17:39:35Z
# 497   2022-10-22T15:57:44Z
# 850   2022-10-22T14:36:01Z
# 898   2022-10-22T14:33:11Z
# 1474  2022-10-22T13:47:54Z
# 1481  2022-10-22T13:47:35Z
# 1489  2022-10-22T13:47:11Z
# 1823  2022-10-22T13:36:22Z
# 1847  2022-10-22T13:35:53Z
# 2091  2022-10-22T13:29:44Z
